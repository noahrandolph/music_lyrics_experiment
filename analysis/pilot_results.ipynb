# %%
import pandas as pd

# %%
pilot_df = pd.read_csv("pilot_results.csv")
pilot_df.head()
# Out:
#   PartitionKey                                             RowKey  \
# 0   musictests  A2JP9IKRHNLRPI5c3845fa-58b4-47e8-bbaf-86d3f393...
# 1   musictests    Aaron Olson1a1e39d2-177f-4457-8e63-6044d3a569d6
# 2   musictests         Adam Jccc14d59-a3cc-4de4-88b3-e019bf15a5f7
# 3   musictests  Camila Hurtado3cf0a44a-413b-4694-be79-970c1491...
# 4   musictests  Camila Hurtado807a4d84-edfd-4738-88b9-ea4976ef...
#
#                   Timestamp Check1 Check1@type Check2 Check2@type Q1  \
# 0  2018-08-03T02:17:09.880Z      A  Edm.String      A  Edm.String  C
# 1  2018-08-03T14:39:33.424Z      A  Edm.String      A  Edm.String  C
# 2  2018-08-03T19:10:51.542Z      A  Edm.String      A  Edm.String  C
# 3  2018-08-03T06:01:58.827Z      A  Edm.String      A  Edm.String  C
# 4  2018-08-03T06:01:58.741Z      A  Edm.String      A  Edm.String  C
#
#       Q1@type Q2     ...      isTurk isTurk@type clickedPlay clickedPlay@type  \
# ...
